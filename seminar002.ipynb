# %%
import pandas as pd

# %%
df = pd.read_csv('./laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0       Inches          Price
# count  1303.00000  1303.000000    1303.000000
# mean    651.00000    15.017191   59870.042910
# std     376.28801     1.426304   37243.201786
# min       0.00000    10.100000    9270.720000
# 25%     325.50000    14.000000   31914.720000
# 50%     651.00000    15.600000   52054.560000
# 75%     976.50000    15.600000   79274.246400
# max    1302.00000    18.400000  324954.720000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.describe(include="object")
# Out:
#        Company  TypeName   ScreenResolution                         Cpu   Ram  \
# count     1303      1303               1303                        1303  1303
# unique      19         6                 40                         118     9
# top       Dell  Notebook  Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# freq       297       727                507                         190   619
#
#            Memory                    Gpu       OpSys Weight
# count        1303                   1303        1303   1303
# unique         39                    110           9    179
# top     256GB SSD  Intel HD Graphics 620  Windows 10  2.2kg
# freq          412                    281        1072    121

# %%
df['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df.Price.min()
# Out:
# 9270.72

# %%
df.Price.max()
# Out:
# 324954.72

# %%
df[df.Price.max() == df.Price]
# Out:
#      Unnamed: 0 Company TypeName  Inches                     ScreenResolution  \
# 196         196   Razer   Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
#
#                              Cpu   Ram   Memory                      Gpu  \
# 196  Intel Core i7 7820HK 2.9GHz  32GB  1TB SSD  Nvidia GeForce GTX 1080
#
#           OpSys  Weight      Price
# 196  Windows 10  3.49kg  324954.72

# %%
df.sort_values(['Price'], ascending=False).iloc[0:10]
# Out:
#       Unnamed: 0 Company     TypeName  Inches  \
# 196          196   Razer       Gaming    17.3
# 830          830   Razer       Gaming    17.3
# 610          610  Lenovo     Notebook    15.6
# 749          749      HP  Workstation    17.3
# 1066        1066    Asus       Gaming    17.3
# 1136        1136      HP  Workstation    17.3
# 238          238    Asus       Gaming    17.3
# 723          723    Dell       Gaming    17.3
# 780          780    Dell       Gaming    17.3
# 1231        1231   Razer       Gaming    14.0
#
#                          ScreenResolution                            Cpu  \
# 196   4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz
# 830   4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz
# 610       IPS Panel 4K Ultra HD 3840x2160  Intel Xeon E3-1535M v6 3.1GHz
# 749           IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz
# 1066          IPS Panel Full HD 1920x1080    Intel Core i7 6820HK 2.7GHz
# ...

# %%
df[df.Inches == df.Inches.min()][['Company','TypeName','Inches','Price']]
# Out:
#      Company            TypeName  Inches       Price
# 50    Lenovo  2 in 1 Convertible    10.1  16996.3200
# 1082  Lenovo  2 in 1 Convertible    10.1  34433.2656
# 1114  Lenovo  2 in 1 Convertible    10.1  29250.7200
# 1126  Lenovo  2 in 1 Convertible    10.1  25521.1200
